# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from geopandas.tools import sjoin
from shapely.geometry import Polygon
from geojson import GeoJSON
import json
import matplotlib
from shapely.geometry import Polygon, mapping
from bokeh.models import (
    ColumnDataSource, GMapPlot, Range1d, ColumnDataSource, LinearAxis,
    HoverTool, PanTool, WheelZoomTool, BoxSelectTool, ResetTool,
    GMapOptions,
    NumeralTickFormatter, PrintfTickFormatter)

from bokeh.models.glyphs import Patches
from bokeh.plotting import figure, save, show
from bokeh.resources import CDN
from bokeh.io import output_file, show

# %%
data = gpd.read_file('../../notGitHub/zillowDC')
data
# Out:
#     State                County        City                      Name  \
# 0      DC  District of Columbia  Washington             Barnaby Woods
# 1      DC  District of Columbia  Washington                  Bellevue
# 2      DC  District of Columbia  Washington                   Benning
# 3      DC  District of Columbia  Washington               Chevy Chase
# 4      DC  District of Columbia  Washington               Dupont Park
# 5      DC  District of Columbia  Washington          Eastland Gardens
# 6      DC  District of Columbia  Washington                   Foxhall
# 7      DC  District of Columbia  Washington                  Ivy City
# 8      DC  District of Columbia  Washington          Judiciary Square
# 9      DC  District of Columbia  Washington                Manor Park
# 10     DC  District of Columbia  Washington          Marshall Heights
# 11     DC  District of Columbia  Washington           Benning Heights
# ...

# %%
polys = list(data.geometry.values)
x = []
y = []
for p in polys:
    x_list = []
    y_list = []
    for t in mapping(p)['coordinates'][0]:
        x_list.append(t[0])
        y_list.append(t[1])
    x.append(x_list)
    y.append(y_list)

# %%
# data.drop('geometry', axis=1, inplace=True)

# %%
data['x'] = x
data['y'] = y

# %%
data2 = pd.DataFrame(data)

# %%
data3 = data2[['x','y']]

# %%
outfp = r"./boquet.html"
gsource = ColumnDataSource(data3)

# %%
map_options = GMapOptions(lat=38.9, lng=-77.02, map_type="roadmap", zoom=12)

plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options)
plot.title.text = "DC"

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool(), HoverTool(), 
            ResetTool())

plot.api_key = 'AIzaSyAzwtLKiUI3B5eqrKRL1MLozbu91hbloYs'

output_file(outfp)
neighborhoods = Patches(xs='x', ys='y',
         fill_color=None,
         fill_alpha=0.4, line_color="black", line_width=1)

plot.add_glyph(gsource, neighborhoods)

show(plot)

# %%
df = gpd.GeoDataFrame(pd.read_pickle('../transit/points_pickle'),crs={'init' :'epsg:4269'})

# %%
df
# Out:
#                     X          Y  UNITNUM  \
# ADDRESS_ID
# 243225     -77.037265  38.936436   1181.0
# 284325     -77.024650  38.920318    917.0
# 294461     -77.081959  38.935867    671.0
# 235844     -77.035880  38.923626    664.0
# 220630     -77.061250  38.943732    638.0
# 224793     -77.082980  38.930830    623.0
# 304584     -77.006294  38.905172    596.0
# 242324     -77.035511  38.906510    582.0
# 219283     -77.055687  38.936190    560.0
# 223988     -77.078747  38.931309    502.0
# 271776     -77.074047  38.922931    495.0
# 297981     -77.061915  38.944880    473.0
# 297629     -77.018323  38.900500    462.0
# 223991     -77.079817  38.928436    457.0
# 303674     -77.007031  38.879532    448.0
# 303694     -77.004968  38.905908    435.0
# 223260     -77.060007  38.944544    435.0
# 274717     -77.061556  38.960421    425.0
# 279770     -77.017406  38.904111    422.0
# 311750     -76.998147  38.900404    413.0
# 308887     -77.090880  38.935943    412.0
# ...

# %%
points = list(df.geometry.values)

# %%
data.crs
# Out:
# {'init': 'epsg:4269'}

# %%
df.shape
# Out:
# (21148, 6)

# %%
agg = gpd.sjoin(df, data, how="inner", op='intersects')

# %%
agg.shape
# Out:
# (21519, 14)

# %%
mofo = agg.groupby('Name')[['score', 'index_right']].mean()

# %%
mofo.shape, agg.shape
# Out:
# ((124, 2), (21519, 15))

# %%
agg['score']=agg['scores'].apply(lambda x: x['score'])

# %%
agg.to_pickle('aggregate')

# %%
agg.head()
# Out:
#                 X          Y  UNITNUM  \
# 243225 -77.037265  38.936436   1181.0
# 236261 -77.043238  38.928401    179.0
# 233596 -77.036811  38.932258    164.0
# 233558 -77.037046  38.931019    151.0
# 233557 -77.037256  38.931797    111.0
#
#                                                    scores  \
# 243225  {'score': 77, 'bikeshare': '0%', 'carshare': '...
# 236261  {'score': 90, 'bikeshare': '16%', 'carshare': ...
# 233596  {'score': 80, 'bikeshare': '15%', 'carshare': ...
# 233558  {'score': 65, 'bikeshare': '0%', 'carshare': '...
# 233557  {'score': 73, 'bikeshare': '0%', 'carshare': '...
#
#                                             geometry  shape_id  index_right  \
# 243225  POINT (-77.03726510819578 38.93643575527931)         8           26
# 236261  POINT (-77.04323777610092 38.92840072027619)         8           26
# 233596   POINT (-77.03681069951871 38.9322579379732)         8           26
# ...

# %%
agg['score'] = agg.scores.apply(lambda x: x['score'])

agg[agg.Name=="Petworth"]
agg[agg.Name=="Fort Davis"].score.value_counts()
# Out:
# 62    6
# 85    6
# 56    4
# 83    4
# 73    4
# 61    2
# 55    2
# 77    2
# 74    2
# 72    2
# 68    2
# 65    2
# 64    2
# Name: score, dtype: int64
